# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors
from sklearn.neighbors import NearestCentroid
import scipy.io as sio
from sklearn.naive_bayes import GaussianNB
from sklearn import cross_validation
from sklearn.metrics import confusion_matrix

x = sio.loadmat('/home/ruben/Documents/HAS/HC-5/i01_maze13_003/i01_maze13_003x_orth.mat')
x_orth = np.transpose(x['x_knn'],[2, 1, 0])
y = np.concatenate(x['label'])

# %%
[n_laps, n_bins, n_lat] = x_orth.shape

# %% [markdown]
# 52 laps with 10 latent dimensions and 150 time points (bins). Next step is the temporal classification with a Naive Bayes classifier. We take a 10 dimensional vector for each lap.

# %%
# %matplotlib inline
n_folds = 3
acc = []
for t in range(n_bins):
    X = np.zeros([n_laps, n_lat])
    for lap in range(n_laps):
        X[lap,:] = x_orth[lap,t,:]
    
    acc_within_fold = []
    for k in range(n_folds):
        X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.3, random_state=k)
        gnb = GaussianNB()
        y_pred = gnb.fit(X_train, y_train).predict(X_test)
        #print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0],(y_test != y_pred).sum()))
        cf = confusion_matrix(y_test, y_pred)
        acc_within_fold.append((cf[0,0] + cf[1,1]))
        
    print("Bin %d = Accuracy (TP+TN/(P+N)) = %1.2f+/-%1.2f%%" % (t, np.mean(acc_within_fold)/X_test.shape[0],np.std(acc_within_fold)/X_test.shape[0]))
    acc.append((np.mean(acc_within_fold)/X_test.shape[0],np.std(acc_within_fold)/X_test.shape[0]))
# Out:
# Bin 0 = Accuracy (TP+TN/(P+N)) = 0.69+/-0.05%
# Bin 1 = Accuracy (TP+TN/(P+N)) = 0.65+/-0.03%
# Bin 2 = Accuracy (TP+TN/(P+N)) = 0.62+/-0.05%
# Bin 3 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.08%
# Bin 4 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.03%
# Bin 5 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 6 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 7 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.03%
# Bin 8 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.11%
# Bin 9 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.11%
# Bin 10 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 11 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.11%
# Bin 12 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 13 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.11%
# Bin 14 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.18%
# Bin 15 = Accuracy (TP+TN/(P+N)) = 0.31+/-0.14%
# Bin 16 = Accuracy (TP+TN/(P+N)) = 0.27+/-0.06%
# Bin 17 = Accuracy (TP+TN/(P+N)) = 0.29+/-0.03%
# Bin 18 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.03%
# Bin 19 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.08%
# Bin 20 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.03%
# Bin 21 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.05%
# Bin 22 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.08%
# Bin 23 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.03%
# Bin 24 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.03%
# Bin 25 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.10%
# Bin 26 = Accuracy (TP+TN/(P+N)) = 0.31+/-0.05%
# Bin 27 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.06%
# Bin 28 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 29 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.00%
# Bin 30 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.05%
# Bin 31 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.11%
# Bin 32 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 33 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.14%
# Bin 34 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.11%
# Bin 35 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.08%
# Bin 36 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.10%
# Bin 37 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 38 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.03%
# Bin 39 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 40 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.08%
# Bin 41 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.08%
# Bin 42 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.08%
# Bin 43 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 44 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.03%
# Bin 45 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 46 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.06%
# Bin 47 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.13%
# Bin 48 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 49 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.06%
# Bin 50 = Accuracy (TP+TN/(P+N)) = 0.29+/-0.03%
# Bin 51 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.06%
# Bin 52 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.06%
# Bin 53 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.06%
# Bin 54 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.08%
# Bin 55 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.10%
# Bin 56 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.12%
# Bin 57 = Accuracy (TP+TN/(P+N)) = 0.60+/-0.13%
# Bin 58 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.13%
# Bin 59 = Accuracy (TP+TN/(P+N)) = 0.60+/-0.11%
# Bin 60 = Accuracy (TP+TN/(P+N)) = 0.56+/-0.10%
# Bin 61 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.13%
# Bin 62 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.12%
# Bin 63 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.11%
# Bin 64 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.08%
# Bin 65 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.12%
# Bin 66 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.11%
# Bin 67 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.14%
# Bin 68 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 69 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.12%
# Bin 70 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.12%
# Bin 71 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.06%
# Bin 72 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.08%
# Bin 73 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.11%
# Bin 74 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.13%
# Bin 75 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.16%
# Bin 76 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.13%
# Bin 77 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.13%
# Bin 78 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.15%
# Bin 79 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.11%
# Bin 80 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.11%
# Bin 81 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.06%
# Bin 82 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.05%
# Bin 83 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.05%
# Bin 84 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.06%
# Bin 85 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.08%
# Bin 86 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.06%
# Bin 87 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.08%
# Bin 88 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 89 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 90 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.11%
# Bin 91 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.12%
# Bin 92 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.13%
# Bin 93 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.10%
# Bin 94 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.03%
# Bin 95 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.03%
# Bin 96 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.03%
# Bin 97 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 98 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.06%
# Bin 99 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.00%
# Bin 100 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.00%
# Bin 101 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.00%
# Bin 102 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 103 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 104 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 105 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.13%
# Bin 106 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.14%
# Bin 107 = Accuracy (TP+TN/(P+N)) = 0.46+/-0.11%
# Bin 108 = Accuracy (TP+TN/(P+N)) = 0.56+/-0.05%
# Bin 109 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.08%
# Bin 110 = Accuracy (TP+TN/(P+N)) = 0.56+/-0.09%
# Bin 111 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.12%
# Bin 112 = Accuracy (TP+TN/(P+N)) = 0.60+/-0.11%
# Bin 113 = Accuracy (TP+TN/(P+N)) = 0.56+/-0.09%
# Bin 114 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.06%
# Bin 115 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.13%
# Bin 116 = Accuracy (TP+TN/(P+N)) = 0.50+/-0.15%
# Bin 117 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 118 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.10%
# Bin 119 = Accuracy (TP+TN/(P+N)) = 0.38+/-0.05%
# Bin 120 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.08%
# Bin 121 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.09%
# Bin 122 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.08%
# Bin 123 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 124 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.10%
# Bin 125 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.06%
# Bin 126 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.06%
# Bin 127 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.15%
# Bin 128 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.06%
# Bin 129 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.03%
# Bin 130 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.12%
# Bin 131 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.11%
# Bin 132 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.06%
# Bin 133 = Accuracy (TP+TN/(P+N)) = 0.58+/-0.03%
# Bin 134 = Accuracy (TP+TN/(P+N)) = 0.52+/-0.11%
# Bin 135 = Accuracy (TP+TN/(P+N)) = 0.54+/-0.08%
# Bin 136 = Accuracy (TP+TN/(P+N)) = 0.48+/-0.03%
# Bin 137 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.05%
# Bin 138 = Accuracy (TP+TN/(P+N)) = 0.40+/-0.06%
# Bin 139 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.03%
# Bin 140 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.06%
# Bin 141 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.03%
# Bin 142 = Accuracy (TP+TN/(P+N)) = 0.31+/-0.00%
# Bin 143 = Accuracy (TP+TN/(P+N)) = 0.33+/-0.06%
# Bin 144 = Accuracy (TP+TN/(P+N)) = 0.31+/-0.00%
# Bin 145 = Accuracy (TP+TN/(P+N)) = 0.27+/-0.06%
# Bin 146 = Accuracy (TP+TN/(P+N)) = 0.29+/-0.08%
# Bin 147 = Accuracy (TP+TN/(P+N)) = 0.35+/-0.06%
# Bin 148 = Accuracy (TP+TN/(P+N)) = 0.44+/-0.14%
# Bin 149 = Accuracy (TP+TN/(P+N)) = 0.42+/-0.11%

# %%
mu = [x[0] for x in acc]
yerr = [x[1] for x in acc]
tbins = range(n_bins)

upper_sd = [m+s for m,s in zip(mu,yerr)]
lower_sd = [m-s for m,s in zip(mu,yerr)]


# plot it!
fig, ax = plt.subplots(1)
ax.plot(tbins, mu, lw=2, label='Acc', color='blue')
ax.fill_between(tbins, upper_sd, lower_sd, facecolor='blue', alpha=0.5)
ax.grid()
ax.set_title('Classification of each time point')
ax.set_xlabel('Bins')
ax.set_ylabel('Classification Acc')

print ("Overall Accuracy (TP+TN/(P+N)) = %1.2f+/-%1.2f%%" % (np.mean(mu), np.max(yerr)))
# Out:
# Overall Accuracy (TP+TN/(P+N)) = 0.45+/-0.18%
